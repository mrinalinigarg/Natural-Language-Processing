# %% [markdown]
# # NLP Basics: Implementing a pipeline to clean text

# %% [markdown]
# ### Pre-processing text data
#
# Cleaning up the text data is necessary to highlight attributes that you're going to want your machine learning system to pick up on. Cleaning (or pre-processing) the data typically consists of a number of steps:
# 1. **Remove punctuation**
# 2. **Tokenization**
# 3. **Remove stopwords**
# 4. Lemmatize/Stem
#
# The first three steps are covered in this chapter as they're implemented in pretty much any text cleaning pipeline. Lemmatizing and stemming are covered in the next chapter as they're helpful but not critical.

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 100)

data = pd.read_csv("SMSSpamCollection.tsv", sep='\t', header=None)#tab seperated, no header
data.columns = ['label', 'body_text']

data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!

# %%
# What does the cleaned version look like?
data_cleaned = pd.read_csv("SMSSpamCollection_cleaned.tsv", sep='\t')
data_cleaned.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                       body_text_nostop
# 0  ['ive', 'searching', 'right', 'words', 'thank', 'breather', 'promise', 'wont', 'take', 'help', '...
# ...

# %% [markdown]
# ### Remove punctuation

# %%
import string
string.punctuation#1.show python what punctuation looks like
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
'I like NLP.'=='I like NLP' # they are different in eyes of python
# Out:
# False

# %%
def rem_punct(text):
    text_nopunct = [char for char in text if char not in string.punctuation] #returns each charachter individually
    return text_nopunct

#we will use lambda function to access the rem-punct method
data['body_text_clean'] = data['body_text'].apply(lambda x: rem_punct(x))
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                        body_text_clean
# 0  [I, v, e,  , b, e, e, n,  , s, e, a, r, c, h, i, n, g,  , f, o, r,  , t, h, e,  , r, i, g, h, t,...
# ...

# %%
def rem_punct(text):
    text_nopunct = "".join([char for char in text if char not in string.punctuation]) #returns each charachter individually. To prevent this we ned to wrap this in no space "".join function
    return text_nopunct

#we will use lambda function to access the rem-punct method
data['body_text_clean'] = data['body_text'].apply(lambda x: rem_punct(x))
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                        body_text_clean
# 0  Ive been searching for the right words to thank you for this breather I promise i wont take your...
# ...

# %% [markdown]
# ### Tokenization

# %%
import re
#splitting into a string of words
def tokenize(text):
    tokens=re.split('\W+',text)#split on 1 or more non-word charachters
    return tokens

data['body_text_tokenized']=data['body_text_clean'].apply(lambda x: tokenize(x.lower()))#python is case-sensitive
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                        body_text_clean  \
# 0  Ive been searching for the right words to thank you for this breather I promise i wont take your...
# ...

# %% [markdown]
# ### Remove stopwords

# %%
import nltk

stopwords= nltk.corpus.stopwords.words('english')
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
def rem_stopwords(tokenized_list):
    text_nostop = [word for word in tokenized_list if word not in stopwords] 
    return text_nostop

#we will use lambda function to access the rem-punct method
data['body_text_nostop'] = data['body_text_tokenized'].apply(lambda x: rem_stopwords(x))
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                        body_text_clean  \
# 0  Ive been searching for the right words to thank you for this breather I promise i wont take your...
# ...
